# %%
import pandas as pd
import os

paths = [
    "/Users/skmishra19/Downloads/dataset/dataset.csv",
    "/Users/skmishra19/Desktop/music_recommendation_system/dataset/dataset.csv",
    "dataset.csv"
]

df = None

for p in paths:
    if os.path.exists(p):
        df = pd.read_csv(p)
        print(f"Loaded dataset from: {p}")
        break

if df is None:
    raise FileNotFoundError(
        f"Dataset not found. Checked paths: {paths}"
    )

print(df.head())
# Out:
# Loaded dataset from: dataset.csv
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# ...

# %%
features = [''
'danceability', 
'energy', 
'acousticness', 
'instrumentalness', 
'liveness', 
'valence', 
'tempo', 
'loudness', 
'popularity'
]

# %%
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(df[features])

knn = NearestNeighbors(
    n_neighbors=11,
    metric='cosine'
)

knn.fit(X)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=11)

# %%
def recommend(song_name):
    
    idx = df[df['track_name'] == song_name].index[0]

    distances, indices = knn.kneighbors(
        X[idx].reshape(1, -1)
    )

    for i in indices[0][1:]:
        print(df.iloc[i]['track_name'])

# %%
recommend("Believer")
# Out:
# We Always Rise
# Para Vestirte Hoy
# Just One Second - Apex Remix
# Fractures (Trivecta Remix)
# Nobody To Love - Extended Mix
# Crash & Burn
# Not Enough
# В диапазоне
# В диапазоне
# Program

# %%
df = df.dropna(subset=features)
df = df.reset_index(drop=True)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X = scaler.fit_transform(df[features])

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(
    n_neighbors=11,
    metric='cosine'
)

knn.fit(X)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=11)

# %%
def recommend(song_name):

    matches = df[
        df['track_name'].str.lower() == song_name.lower()
    ]

    if len(matches) == 0:
        print("Song not found!")
        return

    idx = matches.index[0]

    distances, indices = knn.kneighbors(
        X[idx].reshape(1, -1)
    )

    print("\nRecommended Songs:\n")

    for i in indices[0][1:]:
        print(
            df.iloc[i]['track_name'],
            "-",
            df.iloc[i]['artists']
        )

# %%
recommend("Believer")
# Out:
# Recommended Songs:
#
# We Always Rise - Dither;Deadly Guns;Warface
# Para Vestirte Hoy - Catupecu Machu
# Just One Second - Apex Remix - London Elektricity
# Fractures (Trivecta Remix) - ILLENIUM;Nevve;Trivecta
# Nobody To Love - Extended Mix - Sigma
# Crash & Burn - Tweekacore;Darren Styles;Giin
# Not Enough - Our Lady Peace
# В диапазоне - Pornofilmy
# В диапазоне - Pornofilmy
# Program - Chase & Status;IRAH

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature', 'track_genre']

# %%
df['track_genre'] = df['track_genre'].fillna('Unknown')

# %%
def get_mood(row):

    if row['energy']>0.7 and row['valence']>0.6:
        return 'Happy'
    
    elif row['energy']>0.7:
        return 'Workout'
    elif row['valence']<0.4:
        return 'Sad'
    else:
        return 'Chill'
    

df["mood"] = df.apply(get_mood, axis=1)

# %%
df['mood'] = df.apply(get_mood, axis=1)
